# %%
# %reload_ext autoreload
# %autoreload 2
from exit.modules.mofidtransformer import *
from exit.dataset.dataset import *
from torch.utils.data import dataset, DataLoader
import torch.optim as optim
from torch.optim import optimizer

# %%
device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')

# %%
train_dataset = MOF_pretrain_Dataset('../new_data/E0.pkl')
# Out:
# read ../new_data/E0.pkl...

# %%
train_dataset[0].view(1,-1)
# Out:
# torch.Size([1, 512])

# %%
 train_loader = DataLoader(
        train_dataset, batch_size=32, num_workers=4, drop_last=False, 
        shuffle=True, pin_memory = False
    )

# %%
t = MaskingGenerator()

# %%
t(train_dataset[0].view(1,-1))
# Out:
# (tensor([[  12,  289,   24,   36,   16,   17,   14,   19,   14,   16,   17,   22,
#             19,   18,   36,   24,   36,   14,   17,   22,   19,   14,   16,   14,
#             16,   23,   26,   16,   14,   32,   17,   16,   21,   18,   16,   16,
#             17,   16,   20,   18,   17,   16,   26,   18,   14,   14,   16,   23,
#             26,   16,   16,   17,   16,   14,   14,   17,   16,   16,   17,   16,
#             21,   18,   17,   16,   26,   18,   16, 3528,   16,   23,   14,   16,
#             16,   17,   16,   14,   16,   16, 3590,   16,   23,   17,   16,   16,
#             14,   16,   76,   18,   17,   16,   58,   18,   14,   17,   22,   19,
#             18,   14,   18,   16,   43,   14,   17,   16,   21,   18,   16,   16,
#             17,   14,   20,   14,   17,   16,   26,   18,   16,   14,   22,   19,
#             18,   36,   18,   16,   17,   14,   19,   18,   36,   13,    0,    0,
# ...
